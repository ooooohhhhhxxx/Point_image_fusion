# %%
from PIL import Image
from PIL import ImageDraw
import pandas as pd

# %%
img = Image.new('RGB',(200,200),(0,0,0))
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
png = Image.open('/Users/jinxuanchen/Files_Local/Point_image_fusion/datasets/images/train/00000_00005_00029.png')
png
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img = Image.open('/Volumes/Jin/Data/GTSRB/convert_png/train/00000/00005_00029.png')
a = ImageDraw.ImageDraw(img)
a.rectangle(((9, 10),(100, 99)), fill=None, outline='red', width=1) 
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img = Image.open('/Users/jinxuanchen/Desktop/test/image/train/00000_00000_00027.png')
a = ImageDraw.ImageDraw(img)
a.rectangle(((6, 5),(51, 52)), fill=None, outline='red', width=1) 
xc = (132 - 12)/2 + 12
yc = (136 -13)/2 +13
a.point((28.5,28.5),fill='red',)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img = Image.open(
    '/Users/jinxuanchen/Files_Local/Point_image_fusion/datasets/images/train/00000_00005_00029.png',
)
label = pd.read_table(
    '/Users/jinxuanchen/Desktop/test/dataset/labels/train/00000_00005_00029.txt',header=None,sep=' '
)

# %%
label
# Out:
#    0       1       2      3      4
# 0  0  0.2725  0.2725  0.455  0.445

# %%
x = label.iloc[0, 1]*200
y = label.iloc[0, 2]*200
w = label.iloc[0, 3]
h = label.iloc[0, 4]

o_w = 200 * w
o_h = 200 * h
x1 = x - o_w / 2
y1 = y - o_h / 2
x2 = x + o_w / 2
y2 = y + o_h / 2

# %%
a = ImageDraw.ImageDraw(img)
a.rectangle(((x1, y1),(x2, y2)), fill=None, outline='red', width=2) 
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>
