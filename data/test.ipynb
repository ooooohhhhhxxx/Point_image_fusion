# %%
from PIL import Image
from PIL import ImageDraw

# %%
img = Image.new('RGB',(200,200),(0,0,0))
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
png = Image.open('/Volumes/Jin/Data/GTSRB/convert_png/train/00007/1.png')
png
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 png = Image.open('/Volumes/Jin/Data/GTSRB/convert_png/train/00007/1.png')
#       2 png
#
# File ~/opt/miniconda3/envs/pi/lib/python3.8/site-packages/PIL/Image.py:3092, in open(fp, mode, formats)
#    3089     filename = fp
#    3091 if filename:
# -> 3092     fp = builtins.open(filename, "rb")
#    3093     exclusive_fp = True
#    3095 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/Jin/Data/GTSRB/convert_png/train/00007/1.png'

# %%
img.paste(png,(0,0))
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
img = Image.open('/Volumes/Jin/Data/GTSRB/convert_png/train/00000/00000_00029.png')
a = ImageDraw.ImageDraw(img)
a.rectangle(((12, 13),(132, 136)), fill=None, outline='red', width=1) 
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img = Image.open('/Users/jinxuanchen/Desktop/test/image/train/00000_00000_00027.png')
a = ImageDraw.ImageDraw(img)
a.rectangle(((6, 5),(51, 52)), fill=None, outline='red', width=1) 
xc = (132 - 12)/2 + 12
yc = (136 -13)/2 +13
a.point((28.5,28.5),fill='red',)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
import pandas as pd
x=1
y=2
id =3
out = {
    'id':id,
    'x':x,
    'y':y
}
pd.DataFrame(out,index=[0])
# Out:
#    id  x  y
# 0   3  1  2
